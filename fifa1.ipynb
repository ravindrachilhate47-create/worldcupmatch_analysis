# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Ravindra Chilhate\Downloads\WorldCupMatches.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    str
#  2   Stage                 852 non-null    str
#  3   Stadium               852 non-null    str
#  4   City                  852 non-null    str
#  5   Home Team Name        852 non-null    str
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    str
#  9   Win conditions        852 non-null    str
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    str
#  14  Assistant 1           852 non-null    str
# ...

# %%
df['Datetime']=pd.to_datetime(df['Datetime'],format='mixed')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    datetime64[us]
#  2   Stage                 852 non-null    str
#  3   Stadium               852 non-null    str
#  4   City                  852 non-null    str
#  5   Home Team Name        852 non-null    str
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    str
#  9   Win conditions        852 non-null    str
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    str
#  14  Assistant 1           852 non-null    str
# ...

# %%
df['Home Team Goals']=pd.to_numeric(df['Home Team Goals'].astype("int64"))
# df['Home Team Goals']=df['Home Team Goals'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['Home Team Goals']=pd.to_numeric(df['Home Team Goals'].astype("int64"))
#       2 # df['Home Team Goals']=df['Home Team Goals'].astype('int32')
#
# File c:\Users\Ravindra Chilhate\OneDrive\Desktop\prime_data_analysis\.venv\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# ...
