# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Ravindra Chilhate\Downloads\AB_NYC_2019.csv.zip")

# %%
df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  str
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  str
#  4   neighbourhood_group             48895 non-null  str
#  5   neighbourhood                   48895 non-null  str
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  str
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.dropna()
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %%
df.drop(columns='name',inplace=True)

# %%
df.sample(5)
# Out:
#              id    host_id host_name neighbourhood_group       neighbourhood  \
# 5146    3703633    2119276      Host           Manhattan        East Village
# 35377  28054901   29953329     Yulia            Brooklyn  Bedford-Stuyvesant
# 41998  32636494    3901955      Lena           Manhattan              Harlem
# 43092  33441771  251932107    Nicola            Brooklyn        Williamsburg
# 23166  18753406   51459559   Rossana              Queens             Astoria
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 5146   40.73268  -73.98689  Entire home/apt    195              30
# 35377  40.69371  -73.94449     Private room     53               4
# 41998  40.80556  -73.95497  Entire home/apt    134               7
# 43092  40.71623  -73.96010     Private room     85               2
# 23166  40.75777  -73.91577     Private room     69               5
#
#        number_of_reviews last_review  reviews_per_month  \
# ...

# %%
df['host_name']
# Out:
# 0                John
# 1            Jennifer
# 2           Elisabeth
# 3         LisaRoxanne
# 4               Laura
#              ...
# 48890         Sabrina
# 48891         Marisol
# 48892    Ilgar  Aysel
# 48893             Taz
# 48894      Christophe
# Name: host_name, Length: 48895, dtype: str

# %%
df['host_name']=df['host_name'].str.replace('&','')
df['host_name']=df['host_name'].str.replace('.','')
df['host_name']=df['host_name'].str.replace('-','')
df['host_name']=df['host_name'].str.replace('','')

# %%
df['host_name']=df['host_name'].str.strip()

# %%
df.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df['host_name'] = df['host_name'].fillna("Unknown Host")

# %%
df['neighbourhood_group']
# Out:
# 0         Brooklyn
# 1        Manhattan
# 2        Manhattan
# 3         Brooklyn
# 4        Manhattan
#            ...
# 48890     Brooklyn
# 48891     Brooklyn
# 48892    Manhattan
# 48893    Manhattan
# 48894    Manhattan
# Name: neighbourhood_group, Length: 48895, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   host_id                         48895 non-null  int64
#  2   host_name                       48895 non-null  str
#  3   neighbourhood_group             48895 non-null  str
#  4   neighbourhood                   48895 non-null  str
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  str
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  number_of_reviews               48895 non-null  int64
#  11  last_review                     38843 non-null  str
# ...

# %%
df['last_review']
# Out:
# 0        2018-10-19
# 1        2019-05-21
# 2               NaN
# 3        2019-07-05
# 4        2018-11-19
#             ...
# 48890           NaN
# 48891           NaN
# 48892           NaN
# 48893           NaN
# 48894           NaN
# Name: last_review, Length: 48895, dtype: str

# %%
df['last_review']=df['last_review'].fillna(0)
df['last_review']=pd.to_datetime(df['last_review'],errors='coerce')

# %%
df['last_review']
# Out:
# 0       2018-10-19
# 1       2019-05-21
# 2              NaT
# 3       2019-07-05
# 4       2018-11-19
#            ...
# 48890          NaT
# 48891          NaT
# 48892          NaT
# 48893          NaT
# 48894          NaT
# Name: last_review, Length: 48895, dtype: datetime64[us]

# %%
df['last_review']=df['last_review'].median()
df['last_review']=df['last_review'].fillna(df['last_review'])

# %%
df.drop(columns='last_review',inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df['reviews_per_month']
# Out:
# 0        0.21
# 1        0.38
# 2         NaN
# 3        4.64
# 4        0.10
#          ...
# 48890     NaN
# 48891     NaN
# 48892     NaN
# 48893     NaN
# 48894     NaN
# Name: reviews_per_month, Length: 48895, dtype: float64

# %%
df['reviews_per_month']=df['reviews_per_month'].dropna(how='all')

# %%
df['reviews_per_month']
# Out:
# 0        0.21
# 1        0.38
# 2        0.00
# 3        4.64
# 4        0.10
#          ...
# 48890    0.00
# 48891    0.00
# 48892    0.00
# 48893    0.00
# 48894    0.00
# Name: reviews_per_month, Length: 48895, dtype: float64

# %%
df.iloc[48890:48894]
# Out:
#              id   host_id     host_name neighbourhood_group  \
# 48890  36484665   8232441       Sabrina            Brooklyn
# 48891  36485057   6570630       Marisol            Brooklyn
# 48892  36485431  23492952  Ilgar  Aysel           Manhattan
# 48893  36485609  30985759           Taz           Manhattan
#
#             neighbourhood  latitude  longitude        room_type  price  \
# 48890  Bedford-Stuyvesant  40.67853  -73.94995     Private room     70
# 48891            Bushwick  40.70184  -73.93317     Private room     40
# 48892              Harlem  40.81475  -73.94867  Entire home/apt    115
# 48893      Hell's Kitchen  40.75751  -73.99112      Shared room     55
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 48890               2                  0                0.0
# 48891               4                  0                0.0
# 48892              10                  0                0.0
# 48893               1                  0                0.0
#
# ...

# %%
df['reviews_per_month'] = df['reviews_per_month'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 2
#       1 df['reviews_per_month'] = df['reviews_per_month'].fillna(0)
# ----> 2 df['reviews_per_month'].dtype()
#
# TypeError: 'numpy.dtypes.Float64DType' object is not callable

# %%
df['reviews_per_month']=pd.to_numeric(df['reviews_per_month'],errors='coerce')
df['reviews_per_month']=df['reviews_per_month'].astype("int64")

# %%
df['reviews_per_month']
# Out:
# 0        0
# 1        0
# 2        0
# 3        4
# 4        0
#         ..
# 48890    0
# 48891    0
# 48892    0
# 48893    0
# 48894    0
# Name: reviews_per_month, Length: 48895, dtype: int64
