# %%
import pandas as pd

# %%
df=pd.read_csv("employee_table1.csv")

# %%
df.head(5)
# Out:
#    Customer_ID   First_Name   Last_Name   Age   Email                   \
# 0  EMP001        Anjali       Jain        46    anjalijain@gmailcom
# 1  EMP002        Rahul        Sharma      29    rahul.sharma@gmail.com
# 2  EMP003                     Verma       NaN   verma@gmail.com
# 3  EMP004        Pooja        Mehta       27    pooja.mehta@gmail
# 4  EMP005        Amit         Singh       35    amit@@gmail.com
#
#     Phone        City         Gender    Department   Job_Title   \
# 0   8314829375   LUCKNOW      maleale   Legal        Team lead
# 1   9123456780   Delhi        Male      IT           Developer
# 2   8234567890   Mumbai       Female    HR           Manager
# 3   8123456789   Indore       FEMALE    Finance      Analyst
# 4   9988776655   Delhi        Male      IT           Developer
#
#     Salary          Payment_Amount   Payment_Method   Purchase_Date   Rating  \
# 0   52000           1404668          CREDIT CARD      2024-05-02           5
# ...

# %%
df.isna().sum()
# Out:
# Customer_ID                0
#  First_Name                0
#  Last_Name                 0
#  Age                       0
#  Email                     0
#  Phone                     0
#  City                      0
#  Gender                    0
#  Department                0
#  Job_Title                 0
#  Salary                    0
#  Payment_Amount            0
#  Payment_Method            0
#  Purchase_Date             0
#  Rating                    0
#  Status                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer_ID              20 non-null     str
#  1    First_Name              20 non-null     str
#  2    Last_Name               20 non-null     str
#  3    Age                     20 non-null     str
#  4    Email                   20 non-null     str
#  5    Phone                   20 non-null     str
#  6    City                    20 non-null     str
#  7    Gender                  20 non-null     str
#  8    Department              20 non-null     str
#  9    Job_Title               20 non-null     str
#  10   Salary                  20 non-null     str
#  11   Payment_Amount          20 non-null     str
#  12   Payment_Method          20 non-null     str
#  13   Purchase_Date           20 non-null     str
#  14   Rating                  20 non-null     str
# ...

# %%
df[" First_Name"].str.upper()
# Out:
# 0      ANJALI
# 1      RAHUL
# 2
# 3      POOJA
# 4      AMIT
# 5      SNEHA
# 6      ROHIT
# 7      KAVITA
# 8      ARJUN
# 9      NEHA
# 10     RAJ
# 11     MEENA
# 12     SUNIL
# 13     REKHA
# 14     AJAY
# 15     PRIYA
# 16     KARAN
# 17     TINA
# 18     VIKAS
# 19     SIMRAN
# Name:  First_Name, dtype: str

# %%
df[" Last_Name"].str.upper()
# Out:
# 0      JAIN
# 1      SHARMA
# 2      VERMA
# 3      MEHTA
# 4      SINGH
# 5
# 6      YADAV
# 7      JOSHI
# 8      KUMAR
# 9      SHAH
# 10     PATEL
# 11     GUPTA
# 12     KUMAR
# 13     DAS
# 14     SINGH
# 15     SHARMA
# 16     MEHTA
# 17     KAPOOR
# 18     YADAV
# 19     KAUR
# Name:  Last_Name, dtype: str

# %%
df[" Age"]
# Out:
# 0     46.0000
# 1     29.0000
# 2     32.4375
# 3     27.0000
# 4     35.0000
# 5     24.0000
# 6     32.4375
# 7     31.0000
# 8     45.0000
# 9     26.0000
# 10    33.0000
# 11    28.0000
# 12    40.0000
# 13    32.4375
# 14    36.0000
# 15    25.0000
# 16    29.0000
# 17    32.4375
# 18    38.0000
# 19    27.0000
# Name:  Age, dtype: float64

# %%
# df[" Age"]=pd.to_numeric(df[" Age"],errors="coerce")
# df[" Age"]=df[" Age"].astype("Int")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer_ID              20 non-null     str
#  1    First_Name              20 non-null     str
#  2    Last_Name               20 non-null     str
#  3    Age                     20 non-null     float64
#  4    Email                   20 non-null     str
#  5    Phone                   20 non-null     str
#  6    City                    20 non-null     str
#  7    Gender                  20 non-null     str
#  8    Department              20 non-null     str
#  9    Job_Title               20 non-null     str
#  10   Salary                  20 non-null     str
#  11   Payment_Amount          20 non-null     str
#  12   Payment_Method          20 non-null     str
#  13   Purchase_Date           20 non-null     str
#  14   Rating                  20 non-null     str
# ...

# %%
df[" Email                 "]
# Out:
# 0      anjalijain@gmailcom
# 1      rahul.sharma@gmail.com
# 2      verma@gmail.com
# 3      pooja.mehta@gmail
# 4      amit@@gmail.com
# 5      sneha@gmail.com
# 6      rohit@gmail.com
# 7      kavita@gmailcom
# 8      arjun@gmail.com
# 9      neha@gmail.com
# 10     raj@gmail.com
# 11     meenagupta@gmail.com
# 12     sunil@gmail.com
# 13     rekha@gmail
# 14     ajay@gmail.com
# 15     priya@gmail.com
# 16     karan@gmail
# 17     tina@gmail.com
# 18     vikas@gmail.com
# 19     simran@gmail.com
# Name:  Email                 , dtype: str

# %%
df[" Phone     "]
# Out:
# 0      8314829375
# 1      9123456780
# 2      8234567890
# 3      8123456789
# 4      9988776655
# 5      7896541230
# 6      NaN
# 7      8456123789
# 8      9123987654
# 9      8234512398
# 10     9988123456
# 11     8899776655
# 12     7788996655
# 13     6677889900
# 14     5566778899
# 15     4455667788
# 16     3344556677
# 17     2233445566
# 18     1122334455
# 19     9988771122
# Name:  Phone     , dtype: str

# %%
df[" Phone     "]=pd.to_numeric(df[" Phone     "],errors="coerce")
df[" Phone     "]=df[" Phone     "].fillna(0)
df[" Phone     "]=df[" Phone     "].astype(int)

# %%
df[" City      "].str.upper()
# Out:
# 0      LUCKNOW
# 1      DELHI
# 2      MUMBAI
# 3      INDORE
# 4      DELHI
# 5      BHOPAL
# 6      INDORE
# 7      MUMBAI
# 8      DELHI
# 9
# 10     AHMEDABAD
# 11     JAIPUR
# 12     DELHI
# 13     KOLKATA
# 14     LUCKNOW
# 15     DELHI
# 16     MUMBAI
# 17     DELHI
# 18     BHOPAL
# 19     CHANDIGARH
# Name:  City      , dtype: str

# %%
df[" Gender "].str.strip().str.lower()
# Out:
# 0     maleale
# 1        male
# 2      female
# 3      female
# 4        male
# 5      female
# 6        male
# 7      female
# 8           m
# 9      female
# 10       male
# 11     female
# 12       male
# 13     female
# 14       male
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# Name:  Gender , dtype: str

# %%
df[" Gender "]=df[" Gender "].str.replace("male","M")
df[" Gender "]=df[" Gender "].str.replace("female","F")

# %%
df[" Gender "]
# Out:
# 0         Male
# 1      Male
# 2         FeM
# 3      FEMALE
# 4      Male
# 5         FeM
# 6      Male
# 7         FeM
# 8      m
# 9         FeM
# 10     Male
# 11        FeM
# 12     Male
# 13        FeM
# 14     Male
# 15        feM
# 16     Male
# 17        FeM
# 18     Male
# 19        FeM
# Name:  Gender , dtype: str

# %%
df[" Department"].str.upper()
# Out:
# 0      LEGAL
# 1      IT
# 2      HR
# 3      FINANCE
# 4      IT
# 5      MARKETING
# 6      SALES
# 7      HR
# 8      MANAGEMENT
# 9      FINANCE
# 10     IT
# 11     HR
# 12     FINANCE
# 13     MARKETING
# 14     SALES
# 15     IT
# 16     FINANCE
# 17     HR
# 18     SALES
# 19     MARKETING
# Name:  Department, dtype: str

# %%
df[" Job_Title "].str.upper()
# Out:
# 0      TEAM LEAD
# 1      DEVELOPER
# 2      MANAGER
# 3      ANALYST
# 4      DEVELOPER
# 5      EXECUTIVE
# 6      SALES EXEC
# 7      MANAGER
# 8      DIRECTOR
# 9      ANALYST
# 10     DEVELOPER
# 11     EXECUTIVE
# 12     MANAGER
# 13     EXECUTIVE
# 14     MANAGER
# 15     DEVELOPER
# 16     ANALYST
# 17     MANAGER
# 18     EXECUTIVE
# 19     EXECUTIVE
# Name:  Job_Title , dtype: str

# %%
df[" Salary       "]=pd.to_numeric(df[" Salary       "],errors="coerce")
df[" Salary       "]=df[" Salary       "].fillna(df[" Salary       "].mean())
df[" Salary       "]=df[" Salary       "].astype(int)

# %%
df[" Payment_Amount"]=pd.to_numeric(df[" Payment_Amount"],errors="coerce")
df[" Payment_Amount"]=df[" Payment_Amount"].fillna(df[" Payment_Amount"].mean())
df[" Payment_Amount"]=df[" Payment_Amount"].astype(int)

# %%
df[" Payment_Amount"]
# Out:
# 0     1404668
# 1       50000
# 2      170814
# 3       30000
# 4       70000
# 5       25000
# 6       20000
# 7       40000
# 8     1000000
# 9       35000
# 10      45000
# 11      30000
# 12      80000
# 13     170814
# 14      60000
# 15      30000
# 16      35000
# 17      45000
# 18      40000
# 19      35000
# Name:  Payment_Amount, dtype: int64

# %%
df[" Payment_Method"].str.upper()
# Out:
# 0      CREDIT CARD
# 1      UPI
# 2      CASH
# 3      DEBIT CARD
# 4      CREDIT CARD
# 5      UPI
# 6      CASH
# 7      DEBIT CARD
# 8      CREDIT CARD
# 9      UPI
# 10     CASH
# 11     UPI
# 12     CREDIT CARD
# 13     DEBIT CARD
# 14     CASH
# 15     UPI
# 16     CREDIT CARD
# 17     DEBIT CARD
# 18     CASH
# 19     UPI
# Name:  Payment_Method, dtype: str

# %%
df[" Purchase_Date"]=pd.to_datetime(df[" Purchase_Date"],format="mixed")

# %%
df[" Rating"]=pd.to_numeric(df[" Rating"],errors="coerce")
df[" Rating"]=df[" Rating"].fillna(df[" Rating"].mean())
df[" Rating"]=df[" Rating"].astype(int)

# %%
df[" Status"].str.upper()
# Out:
# 0        ACTIVE
# 1        ACTIVE
# 2        ACTIVE
# 3      INACTIVE
# 4        ACTIVE
# 5        ACTIVE
# 6      INACTIVE
# 7        ACTIVE
# 8        ACTIVE
# 9        ACTIVE
# 10       ACTIVE
# 11     INACTIVE
# 12       ACTIVE
# 13       ACTIVE
# 14       ACTIVE
# 15       ACTIVE
# 16     INACTIVE
# 17       ACTIVE
# 18       ACTIVE
# 19       ACTIVE
# Name:  Status, dtype: str

# %%
df.to_csv("xx_com_clean.csv")
